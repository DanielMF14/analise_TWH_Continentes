# %% [markdown]
# # Vamos fazer uma análise sobre o consumo de twh por continente.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as scp

# %%
# Criamos um DataFrame que recebe a nossa base de dados e passamos a coluna de anos como o nosso índice:
df_Continente = pd.read_csv("Continent_Consumption_TWH.xls", index_col="Year")
df_Continente
# Out:
#           World      OECD     BRICS    Europe  North America  Latin America  \
# Year
# 1990  101855.54  52602.49  26621.07  20654.88       24667.23        5373.06
# 1991  102483.56  53207.25  26434.99  20631.62       24841.68        5500.99
# 1992  102588.23  53788.75  25993.05  20189.68       25341.77        5628.92
# 1993  103646.56  54614.48  26283.80  20189.68       25830.23        5675.44
# 1994  104449.03  55579.77  25993.05  20085.01       26365.21        5989.45
# 1995  107112.30  56754.40  26946.71  20713.03       26714.11        6024.34
# 1996  109763.94  58417.49  27481.69  21445.72       27295.61        6303.46
# 1997  110903.68  59022.25  27446.80  21341.05       27574.73        6570.95
# 1998  111450.29  59219.96  27528.21  21503.87       27772.44        6803.55
# 1999  113974.00  60301.55  28319.05  21306.16       28528.39        6989.63
# 2000  116590.75  61685.52  28923.81  21538.76       29342.49        7024.52
# 2001  117521.15  61452.92  29528.57  21934.18       28795.88        7036.15
# 2002  120207.68  61987.90  30552.01  21969.07       29156.41        7280.38
# 2003  124464.26  62871.78  33157.13  22515.68       29377.38        7501.35
# 2004  129953.62  64058.04  35994.85  22748.28       29993.77        7780.47
# 2005  133582.18  64453.46  38169.66  22864.58       30168.22        8059.59
# 2006  137396.82  64616.28  40670.11  23108.81       29958.88        8303.82
# 2007  141211.46  64883.77  43112.41  22829.69       30424.08        8571.31
# 2008  142874.55  64034.78  44635.94  22829.69       29644.87        8780.65
# 2009  141490.58  61197.06  46426.96  21608.54       28214.38        8559.68
# 2010  149294.31  63255.57  50323.01  22469.16       28830.77        9117.92
# 2011  151783.13  62127.46  53207.25  21794.62       28598.17        9304.00
# 2012  153748.60  61685.52  54975.01  21689.95       28167.86        9594.75
# 2013  155958.30  62080.94  56068.23  21480.61       28667.95        9978.54
# 2014  157667.91  61499.44  57405.68  20689.77       29063.37        9943.65
# 2015  158086.59  61511.07  57533.61  21038.67       28784.25        9873.87
# 2016  159377.52  61545.96  57742.95  21224.75       28563.28        9745.94
# 2017  162459.47  61929.75  59429.30  21620.17       28563.28        9687.79
# 2018  166297.37  62592.66  61673.89  21399.20       29470.42        9513.34
# 2019  167553.41  61825.08  63255.57  21061.93       29249.45        9478.45
# 2020  160819.64  57487.09  63162.53  19643.07       27063.01        8815.54
#
#           Asia  Pacific   Africa  Middle-East       CIS
# Year
# 1990  24574.19  1197.89  4407.77      2581.86  16049.40
# 1991  24783.53  1186.26  4535.70      2744.68  15898.21
# 1992  25690.67  1209.52  4582.22      3081.95  14339.79
# 1993  26876.93  1267.67  4721.78      3349.44  13246.57
# 1994  28098.08  1279.30  4803.19      3640.19  11606.74
# 1995  29761.17  1290.93  5000.90      3744.86  11188.06
# 1996  30772.98  1372.34  5152.09      3814.64  10850.79
# 1997  31435.89  1407.23  5280.02      4058.87  10373.96
# 1998  31331.22  1442.12  5431.21      4082.13  10152.99
# 1999  32412.81  1477.01  5559.14      4244.95  10373.96
# 2000  33564.18  1500.27  5617.29      4314.73  10501.89
# 2001  34227.09  1477.01  5756.85      4663.63  10571.67
# 2002  35680.84  1523.53  5849.89      4884.60  10653.08
# 2003  38181.29  1535.16  6140.64      4954.38  11036.87
# 2004  41437.69  1558.42  6466.28      5245.13  11188.06
# 2005  43693.91  1570.05  6652.36      5675.44  11222.95
# 2006  46124.58  1616.57  6861.70      5989.45  11548.59
# 2007  48555.25  1663.09  7129.19      6315.09  11664.89
# 2008  49636.84  1721.24  7443.20      6850.07  11874.23
# 2009  51858.17  1721.24  7606.02      7059.41  10967.09
# 2010  56010.08  1732.87  7803.73      7361.79  11804.45
# 2011  58324.45  1744.50  8117.74      7524.61  12164.98
# 2012  60022.43  1744.50  8303.82      7943.29  12269.65
# 2013  61499.44  1767.76  8431.75      8071.22  12002.16
# 2014  62895.04  1767.76  8896.95      8513.16  11699.78
# 2015  63476.54  1767.76  8838.80      8675.98  11222.95
# 2016  63941.74  1767.76  9106.29      8862.06  11595.11
# 2017  65721.13  1791.02  9304.00      9210.96  11792.82
# 2018  68035.50  1791.02  9559.86      9257.48  12385.95
# 2019  69582.29  1802.65  9641.27      9455.19  12490.62
# 2020  69256.65  1767.76  9408.67      9338.89  11804.45

# %% [markdown]
# * Vamos fazer uma análise do consumo(TWH) por continente. Mas antes, vamos ver o consumo total por ano.

# %%
# Vamos criar um novo DF que contém os dados total de consumo:
df_Consumo_World = df_Continente['World']
df_Consumo_World
# Out:
# Year
# 1990    101855.54
# 1991    102483.56
# 1992    102588.23
# 1993    103646.56
# 1994    104449.03
# 1995    107112.30
# 1996    109763.94
# 1997    110903.68
# 1998    111450.29
# 1999    113974.00
# 2000    116590.75
# 2001    117521.15
# 2002    120207.68
# 2003    124464.26
# 2004    129953.62
# 2005    133582.18
# 2006    137396.82
# 2007    141211.46
# 2008    142874.55
# 2009    141490.58
# 2010    149294.31
# 2011    151783.13
# 2012    153748.60
# 2013    155958.30
# 2014    157667.91
# 2015    158086.59
# 2016    159377.52
# 2017    162459.47
# 2018    166297.37
# 2019    167553.41
# 2020    160819.64
# Name: World, dtype: float64

# %% [markdown]
# * Vamos plotar um gráfico de linha para ver nossas séries temporais:

# %%
# Criar uma figura e área de plotagem:
fig, ax = plt.subplots(figsize=(16,8)) 

# Adicionando titulo à figura:
plt.suptitle("Consumo de Terawatt-hora (TWh) no mundo ao longo de 30 anos.", fontsize=20, weight='bold')

# Plotar a série temporal(Gráfico de linhas):
ax.plot(df_Consumo_World, label='Consumo anual')

# Dá titulo aos eixos:
ax.set_xlabel("Anos", fontsize=14)
ax.set_ylabel("Consumo(TWH)", fontsize=14)

# Adicionar todos os anos no eixo X
ax.set_xticks(df_Consumo_World.index)  # Assumindo que o índice do DataFrame contém os anos
ax.set_xticklabels(df_Consumo_World.index, rotation=45)  # Gira os anos para melhor visualização

# Adicionando a legenda:
ax.legend()
#Plotando:
plt.show()

# %% [markdown]
# * Agora vamos ver o consumo de TWH na Europa.

# %%
# Novamente vamos filtrar somente um variável, no caso, o continente europeu:
df_Consumo_Europa = df_Continente['Europe']
df_Consumo_Europa
# Out:
# Year
# 1990    20654.88
# 1991    20631.62
# 1992    20189.68
# 1993    20189.68
# 1994    20085.01
# 1995    20713.03
# 1996    21445.72
# 1997    21341.05
# 1998    21503.87
# 1999    21306.16
# 2000    21538.76
# 2001    21934.18
# 2002    21969.07
# 2003    22515.68
# 2004    22748.28
# 2005    22864.58
# 2006    23108.81
# 2007    22829.69
# 2008    22829.69
# 2009    21608.54
# 2010    22469.16
# 2011    21794.62
# 2012    21689.95
# 2013    21480.61
# 2014    20689.77
# 2015    21038.67
# 2016    21224.75
# 2017    21620.17
# 2018    21399.20
# 2019    21061.93
# 2020    19643.07
# Name: Europe, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16,8))

plt.suptitle("Consumo de Terawatt-hora (TWh) na Europa ao longo de 30 anos.", fontsize=20, weight='semibold')

ax.plot(df_Consumo_Europa, label='Consumo anual europeu')

ax.set_xlabel('Anos', fontsize=14, labelpad=20)
ax.set_ylabel('Consumo por ano', fontsize=14, labelpad=20)

# Adicionar todos os anos no eixo X
ax.set_xticks(df_Consumo_Europa.index)  # Assumindo que o índice do DataFrame contém os anos
ax.set_xticklabels(df_Consumo_Europa.index, rotation=45)  # Gira os anos para melhor visualização

ax.legend()
plt.show()

# %% [markdown]
# * Vamos ver a média móvel do consumo anual de TWH.

# %%
# Calculando as médias móveis:
df_rolling_12m = df_Consumo_Europa.rolling(window=12).mean()
df_rolling_6m = df_Consumo_Europa.rolling(window=6).mean()

# %%
fig, ax = plt.subplots(figsize=(16,8))

plt.suptitle("Consumo de Terawatt-hora (TWh) na Europa ao longo de 30 anos.", fontsize=20, weight='semibold')

ax.plot(df_Consumo_Europa.index, df_Consumo_Europa, label='Consumo anual europeu')
ax.plot(df_Consumo_Europa.index,df_rolling_6m, label='Média móvel (6 meses)')
ax.plot(df_Consumo_Europa.index,df_rolling_12m, label='Média móvel (12 meses)')

# Adicionar todos os anos no eixo X
ax.set_xticks(df_Consumo_World.index)  # Assumindo que o índice do DataFrame contém os anos
ax.set_xticklabels(df_Consumo_World.index, rotation=45)  # Gira os anos para melhor visualização

ax.set_xlabel('Anos', fontsize=14, labelpad=20)
ax.set_ylabel('Consumo por ano', fontsize=14, labelpad=20)

ax.legend()
plt.show()

# %% [markdown]
# * Vamos ver o consumo de TWH na América do Norte.

# %%
df_Consumo_AmericaNorte = df_Continente['North America']
df_Consumo_AmericaNorte
# Out:
# Year
# 1990    24667.23
# 1991    24841.68
# 1992    25341.77
# 1993    25830.23
# 1994    26365.21
# 1995    26714.11
# 1996    27295.61
# 1997    27574.73
# 1998    27772.44
# 1999    28528.39
# 2000    29342.49
# 2001    28795.88
# 2002    29156.41
# 2003    29377.38
# 2004    29993.77
# 2005    30168.22
# 2006    29958.88
# 2007    30424.08
# 2008    29644.87
# 2009    28214.38
# 2010    28830.77
# 2011    28598.17
# 2012    28167.86
# 2013    28667.95
# 2014    29063.37
# 2015    28784.25
# 2016    28563.28
# 2017    28563.28
# 2018    29470.42
# 2019    29249.45
# 2020    27063.01
# Name: North America, dtype: float64

# %%
# Para automatizar o processo de criação de gráficos vamos criar uma função para plotar o consumo de TWH p/continente: 
def plot_time_series(data, y_col, title, xlabel, ylabel, figsize=(18, 6), label_line=None):
    """
    Função para plotar gráficos de séries temporais.
    
    Parâmetros:
    - data (pd.DataFrame): DataFrame contendo os dados.
    - y_col (str): Nome da coluna a ser plotada no eixo Y.
    - title (str): Título do gráfico.
    - xlabel (str): Rótulo do eixo X.
    - ylabel (str): Rótulo do eixo Y.
    - figsize (tuple): Tamanho da figura (largura, altura).
    - label_line (str): Rótulo da linha no gráfico (para legenda).
    
    Retorno:
    - Nenhum. Exibe o gráfico.
    """
    # Cria figura e área de plotagem
    fig, ax = plt.subplots(figsize=figsize)

    # Adiciona título à figura
    plt.suptitle(title, fontsize=20, weight='bold')

    # Plota série temporal
    ax.plot(data, label=label_line if label_line else y_col)

    # Define os títulos dos eixos
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    # Configura o eixo X para mostrar todos os anos
    ax.set_xticks(data.index)  # Define os ticks como todos os valores do índice
    ax.set_xticklabels(data.index, rotation=45)  # Rotaciona para legibilidade

    # Adiciona legenda
    if label_line or y_col:
        ax.legend()

    # Mostra o gráfico
    plt.show()

# %%
plot_time_series(df_Consumo_AmericaNorte,"Consumo de TWH", "Consumo de TWH anual Norte Americano", "Ano", "Consumo", (18,8), 'Variação de consumo')

# %% [markdown]
# * Vamos ver a média móvel na América do Norte.

# %%
df_rolling_AN_6m = df_Consumo_AmericaNorte.rolling(window=6).mean()
df_rolling_AN_12m = df_Consumo_AmericaNorte.rolling(window=12).mean()

# %%
fig, ax = plt.subplots(figsize=(16,8))

plt.suptitle("Consumo de Terawatt-hora (TWh) na América do Norte ao longo de 30 anos.", fontsize=20, weight='semibold')

ax.plot(df_Consumo_AmericaNorte, label='Consumo anual norte americano.')
ax.plot(df_rolling_AN_6m, label='Média móvel (6 meses)')
ax.plot(df_rolling_AN_12m, label='Média móvel (12 meses)')

# Adicionar todos os anos no eixo X
ax.set_xticks(df_Consumo_AmericaNorte.index)  # Assumindo que o índice do DataFrame contém os anos
ax.set_xticklabels(df_Consumo_AmericaNorte.index, rotation=45)  # Gira os anos para melhor visualização

ax.set_xlabel('Anos', fontsize=14, labelpad=20)
ax.set_ylabel('Consumo por ano', fontsize=14, labelpad=20)

ax.legend()
plt.show()

# %% [markdown]
# * Agora vamos ver o consumo de TWH na América Latina.

# %%
df_Consumo_AmericaLatina = df_Continente['Latin America']
df_Consumo_AmericaLatina
# Out:
# Year
# 1990    5373.06
# 1991    5500.99
# 1992    5628.92
# 1993    5675.44
# 1994    5989.45
# 1995    6024.34
# 1996    6303.46
# 1997    6570.95
# 1998    6803.55
# 1999    6989.63
# 2000    7024.52
# 2001    7036.15
# 2002    7280.38
# 2003    7501.35
# 2004    7780.47
# 2005    8059.59
# 2006    8303.82
# 2007    8571.31
# 2008    8780.65
# 2009    8559.68
# 2010    9117.92
# 2011    9304.00
# 2012    9594.75
# 2013    9978.54
# 2014    9943.65
# 2015    9873.87
# 2016    9745.94
# 2017    9687.79
# 2018    9513.34
# 2019    9478.45
# 2020    8815.54
# Name: Latin America, dtype: float64

# %%
plot_time_series(df_Consumo_AmericaLatina, "Consumo de TWH", "Consumo anual de TWH na América Latina", "Ano", "Consumo", (18,8), "Variação de consumo")

# %%
df_rolling_AL_12m = df_Consumo_AmericaLatina.rolling(window=12).mean()
df_rolling_AL_6m = df_Consumo_AmericaLatina.rolling(window=6).mean()

# %%
fig, ax = plt.subplots(figsize=(16,8))

plt.suptitle("Consumo de Terawatt-hora (TWh) na América Latina ao longo de 30 anos.", fontsize=20, weight='semibold')

ax.plot(df_Consumo_AmericaLatina, label='Consumo anual latino-americano.')
ax.plot(df_rolling_AL_6m, label='Média móvel (6 meses)')
ax.plot(df_rolling_AL_12m, label='Média móvel (12 meses)')

# Adicionar todos os anos no eixo X
ax.set_xticks(df_Consumo_AmericaLatina.index)  # Assumindo que o índice do DataFrame contém os anos
ax.set_xticklabels(df_Consumo_AmericaLatina.index, rotation=45)  # Gira os anos para melhor visualização

ax.set_xlabel('Anos', fontsize=14, labelpad=20)
ax.set_ylabel('Consumo por ano', fontsize=14, labelpad=20)

ax.legend()
plt.show()
